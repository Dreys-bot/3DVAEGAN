# %%
import pickle

with open('../output/image/model=3DGAN_cube=32_bs=32_g_lr=0.0025_d_lr=0.001_z=norm_bias=False_sl=False/tensor(20.).pkl', 'rb') as f:
   model_data = pickle.load(f)

# %%
model_data
# Out:
# array([[[[False, False,  True, ..., False,  True, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False,  True, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [ True, False, False, ..., False, False, False]],
#
#         [[False,  True,  True, ..., False,  True, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
# ...

# %%
import trimesh

mesh = trimesh.Trimesh(vertex=model_data['vertices'], 
                       faces=model_data['faces'])
mesh.export('model.obj')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Documents Personnels\Projets\Portfolio project\Generative 3D\Multiview-3D-VAE-GAN-master\Multiview-3D-VAE-GAN-master\3D_GAN\test.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/d%3A/Documents%20Personnels/Projets/Portfolio%20project/Generative%203D/Multiview-3D-VAE-GAN-master/Multiview-3D-VAE-GAN-master/3D_GAN/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import trimesh
# ----> <a href='vscode-notebook-cell:/d%3A/Documents%20Personnels/Projets/Portfolio%20project/Generative%203D/Multiview-3D-VAE-GAN-master/Multiview-3D-VAE-GAN-master/3D_GAN/test.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> mesh = trimesh.Trimesh(vertex=model_data['vertices'],
# ...
